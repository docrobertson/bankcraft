# %% [markdown]
# # Welcome to BankCraft
# ====================

# %%
from bankcraft.bankcraftmodel import BankCraftModel
from bankcraft.utils.visualization import Visualization

model = BankCraftModel(num_people=100, initial_money=1000, num_banks=3, width=15, height=15)

model.run(1)

vis = Visualization(model)
vis.grid_plot()
# Out:
# (<Figure size 1000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Agent Positions on Grid'}, xlabel='X Position', ylabel='Y Position'>)
